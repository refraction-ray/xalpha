# %%
import xalpha as xa
import pandas as pd
xa.set_display("notebook")
# Out:
# holdings.py is found and loaded within xalpha dir

# %% [markdown]
# 我们探索下 xalpha 的交易模拟功能，以回测一系列主动基虚拟交易为例

# %% [markdown]
# ## 基金池
#
# ### 绝对收益
# * 广发趋势优选 000215
# * 安信稳健增值  001316
# * 海富通阿尔法 519062
#
# ### 债基混合
# * 鹏华丰禄 003547 0 股票仓位
# * 易方达丰和 002969 15 股票仓位
# * 易方达裕翔 002351 25 股票仓位
# * 易方达安心回馈 001182 40 股票仓位
#
# ### 股基混合
# * 519697 交银优势行业
# * 519732 交银双息
# * 163415 兴权商业模式优选
#
# ### 进攻纯股基
# * 001178 前海再融资
# * 001938 中欧时代先锋
# * 000751 嘉实新兴产业

# %%
fundlist = [
    "000215",
    "001316",
    "519062",
    "003547",
    "002969",
    "002351",
    "001182",
    "519697",
    "519732",
    "163415",
    "001178",
    "001938",
    "000751",
]

# %%
infolist = [xa.fundinfo(code) for code in fundlist]

# %%
startdate = [f.price.iloc[0].date for f in infolist]
startdate
# 看一下这些基金是从什么时候创建的
# Out:
# [Timestamp('2013-09-11 00:00:00'),
#  Timestamp('2015-05-25 00:00:00'),
#  Timestamp('2014-11-20 00:00:00'),
#  Timestamp('2016-10-27 00:00:00'),
#  Timestamp('2016-11-23 00:00:00'),
#  Timestamp('2016-01-22 00:00:00'),
#  Timestamp('2015-05-29 00:00:00'),
#  Timestamp('2009-01-21 00:00:00'),
#  Timestamp('2013-09-04 00:00:00'),
#  Timestamp('2012-12-18 00:00:00'),
#  Timestamp('2015-05-18 00:00:00'),
#  Timestamp('2015-11-03 00:00:00'),
#  Timestamp('2014-09-17 00:00:00')]

# %% [markdown]
# 那么我们从20170101开始一揽子买入, 先写个账单

# %%
df = pd.DataFrame([[1000 for _ in fundlist]], columns=fundlist)

# %%
df["date"] = pd.datetime(2017, 1, 1)
df
# Out:
# /usr/local/Cellar/python3/3.6.3/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime instead.
#   """Entry point for launching an IPython kernel.
#    000215  001316  519062  003547  002969  002351  001182  519697  519732  \
# 0    1000    1000    1000    1000    1000    1000    1000    1000    1000
#
#    163415  001178  001938  000751       date
# 0    1000    1000    1000    1000 2017-01-01

# %%
sys=xa.mul(status=df) # 获取模拟交易组合

# %%
sys.summary()  
# 可以看出至今收益贡献最大的是交银双息和嘉实新兴
# Out:
#              基金名称    基金代码    当日净值    单位成本    持有份额      基金现值    基金总申购   历史最大占用  \
# 13             总计   total     NaN     NaN     NaN  19675.82  13000.0  13000.0
# 12       嘉实新兴产业股票  000751  3.7580  1.4892  671.49   2523.46   1000.0   1000.0
# 8    交银定期支付双息平衡混合  519732  4.3000  2.0931  477.75   2054.33   1000.0   1000.0
# 9      兴全商业模式优选混合  163415  2.5050  1.3781  725.65   1817.75   1000.0   1000.0
# 6       易方达安心回馈混合  001182  1.8640  1.0981  910.67   1697.49   1000.0   1000.0
# 7        交银优势行业混合  519697  4.3000  2.5531  365.88   1573.28   1000.0   1000.0
# 11      中欧时代先锋股票A  001938  1.6697  0.7368  916.06   1529.55   1000.0   1000.0
# 10      前海开源再融资股票  001178  1.6580  0.9057  888.35   1472.88   1000.0   1000.0
# 5       易方达裕祥回报债券  002351  1.4390  1.0230  977.50   1406.62   1000.0   1000.0
# 4         易方达丰和债券  002969  1.2705  1.0051  994.92   1264.05   1000.0   1000.0
# 1       安信稳健增值混合A  001316  1.3561  1.0421  911.50   1236.09   1000.0   1000.0
# 3          鹏华丰禄债券  003547  1.0891  0.8525  999.50   1088.56   1000.0   1000.0
# 0   广发趋势优选灵活配置混合A  000215  1.6152  1.1712  669.68   1081.67   1000.0   1000.0
# 2     海富通阿尔法对冲混合A  519062  1.1420  0.8208  814.44    930.09   1000.0   1000.0
#
#       基金持有成本  基金分红与赎回       换手率   基金收益总额     投资收益率
# 13  11668.51  1331.49  0.163704  8007.31   61.5947
# 12   1000.00     0.00  0.148495  1523.46  152.3460
# 8    1000.00     0.00  0.148495  1054.33  105.4330
# 9    1000.00     0.00  0.148495   817.75   81.7750
# 6    1000.00     0.00  0.148495   697.49   69.7490
# 7     934.14    65.86  0.158275   639.14   63.9140
# 11    674.99   325.01  0.196757   854.56   85.4560
# 10    804.56   195.44  0.177517   668.32   66.8320
# 5    1000.00     0.00  0.148495   406.62   40.6620
# 4    1000.00     0.00  0.148616   264.05   26.4050
# 1     949.87    50.13  0.155939   286.22   28.6220
# 3     852.07   147.93  0.170462   236.49   23.6490
# 0     784.36   215.64  0.180516   297.31   29.7310
# 2     668.52   331.48  0.197718   261.57   26.1570

# %% [markdown]
# 你还可以查看任意天数的投资概览

# %%
sys.summary("2018-11-01") # 熊市时刻，还是保持了相当的正收益
# Out:
#              基金名称    基金代码    当日净值    单位成本    持有份额      基金现值    基金总申购   历史最大占用  \
# 13             总计   total     NaN     NaN     NaN  13894.30  13000.0  13000.0
# 8    交银定期支付双息平衡混合  519732  2.6000  2.0931  477.75   1242.15   1000.0   1000.0
# 12       嘉实新兴产业股票  000751  1.7670  1.4892  671.49   1186.52   1000.0   1000.0
# 2     海富通阿尔法对冲混合A  519062  1.4140  1.2278  814.44   1151.62   1000.0   1000.0
# 6       易方达安心回馈混合  001182  1.2460  1.0981  910.67   1134.69   1000.0   1000.0
# 4         易方达丰和债券  002969  1.1158  1.0051  994.92   1110.13   1000.0   1000.0
# 1       安信稳健增值混合A  001316  1.1810  1.0421  911.50   1076.48   1000.0   1000.0
# 5       易方达裕祥回报债券  002351  1.0960  1.0230  977.50   1071.34   1000.0   1000.0
# 3          鹏华丰禄债券  003547  1.0679  0.9675  999.50   1067.37   1000.0   1000.0
# 0   广发趋势优选灵活配置混合A  000215  1.5900  1.3602  669.68   1064.79   1000.0   1000.0
# 7        交银优势行业混合  519697  2.8580  2.5531  365.88   1045.69   1000.0   1000.0
# 11      中欧时代先锋股票A  001938  1.0609  0.8376  916.06    971.85   1000.0   1000.0
# 9      兴全商业模式优选混合  163415  1.3140  1.3781  725.65    953.50   1000.0   1000.0
# 10      前海开源再融资股票  001178  0.9210  0.9057  888.35    818.17   1000.0   1000.0
#
#       基金持有成本  基金分红与赎回       换手率   基金收益总额    投资收益率
# 13  12333.85   666.15  0.287634  1560.45  12.0035
# 8    1000.00     0.00  0.273613   242.15  24.2150
# 12   1000.00     0.00  0.273613   186.52  18.6520
# 2    1000.00     0.00  0.273613   151.62  15.1620
# 6    1000.00     0.00  0.273613   134.69  13.4690
# 4    1000.00     0.00  0.274024   110.13  11.0130
# 1     949.87    50.13  0.287329   126.61  12.6610
# 5    1000.00     0.00  0.273613    71.34   7.1340
# 3     967.02    32.98  0.282637   100.35  10.0350
# 0     910.93    89.07  0.297984   153.86  15.3860
# 7     934.14    65.86  0.291633   111.55  11.1550
# 11    767.33   232.67  0.337275   204.52  20.4520
# 9    1000.00     0.00  0.273613   -46.50  -4.6500
# 10    804.56   195.44  0.327088    13.61   1.3610

# %%
# 计算一下投资内部收益率
sys.xirrrate() # 年化15%
# Out:
# 0.16012079565769144

# %%
# 计算一下 2018年的内部收益率
sys.xirrrate(date="2018-12-31", startdate="2018-01-01")
# Out:
# -0.041628407100152635

# %%
sys.v_positions()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="c56e98f1053f478cbc442e8f4a31a820" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_c56e98f1053f478cbc442e8f4a31a820 = echarts.init(
#                     document.getElementById('c56e98f1053f478cbc442e8f4a31a820'), 'white', {renderer: 'canvas'});
#                 var option_c56e98f1053f478cbc442e8f4a31a820 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "name": "\u603b\u503c\u5360\u6bd4",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u5609\u5b9e\u65b0\u5174\u4ea7\u4e1a\u80a1\u7968",
#                     "value": 2523.46
#                 },
#                 {
#                     "name": "\u4ea4\u94f6\u5b9a\u671f\u652f\u4ed8\u53cc\u606f\u5e73\u8861\u6df7\u5408",
#                     "value": 2054.33
#                 },
#                 {
#                     "name": "\u5174\u5168\u5546\u4e1a\u6a21\u5f0f\u4f18\u9009\u6df7\u5408",
#                     "value": 1817.75
#                 },
#                 {
#                     "name": "\u6613\u65b9\u8fbe\u5b89\u5fc3\u56de\u9988\u6df7\u5408",
#                     "value": 1697.49
#                 },
#                 {
#                     "name": "\u4ea4\u94f6\u4f18\u52bf\u884c\u4e1a\u6df7\u5408",
#                     "value": 1573.28
#                 },
#                 {
#                     "name": "\u4e2d\u6b27\u65f6\u4ee3\u5148\u950b\u80a1\u7968A",
#                     "value": 1529.55
#                 },
#                 {
#                     "name": "\u524d\u6d77\u5f00\u6e90\u518d\u878d\u8d44\u80a1\u7968",
#                     "value": 1472.88
#                 },
#                 {
#                     "name": "\u6613\u65b9\u8fbe\u88d5\u7965\u56de\u62a5\u503a\u5238",
#                     "value": 1406.62
#                 },
#                 {
#                     "name": "\u6613\u65b9\u8fbe\u4e30\u548c\u503a\u5238",
#                     "value": 1264.05
#                 },
#                 {
#                     "name": "\u5b89\u4fe1\u7a33\u5065\u589e\u503c\u6df7\u5408A",
#                     "value": 1236.09
#                 },
#                 {
#                     "name": "\u9e4f\u534e\u4e30\u7984\u503a\u5238",
#                     "value": 1088.56
#                 },
#                 {
#                     "name": "\u5e7f\u53d1\u8d8b\u52bf\u4f18\u9009\u7075\u6d3b\u914d\u7f6e\u6df7\u5408A",
#                     "value": 1081.67
#                 },
#                 {
#                     "name": "\u6d77\u5bcc\u901a\u963f\u5c14\u6cd5\u5bf9\u51b2\u6df7\u5408A",
#                     "value": 930.09
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": false,
#                 "position": "center",
#                 "margin": 8
#             },
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "formatter": "{a} <br/>{b}: {c} ({d}%)",
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5609\u5b9e\u65b0\u5174\u4ea7\u4e1a\u80a1\u7968",
#                 "\u4ea4\u94f6\u5b9a\u671f\u652f\u4ed8\u53cc\u606f\u5e73\u8861\u6df7\u5408",
#                 "\u5174\u5168\u5546\u4e1a\u6a21\u5f0f\u4f18\u9009\u6df7\u5408",
#                 "\u6613\u65b9\u8fbe\u5b89\u5fc3\u56de\u9988\u6df7\u5408",
#                 "\u4ea4\u94f6\u4f18\u52bf\u884c\u4e1a\u6df7\u5408",
#                 "\u4e2d\u6b27\u65f6\u4ee3\u5148\u950b\u80a1\u7968A",
#                 "\u524d\u6d77\u5f00\u6e90\u518d\u878d\u8d44\u80a1\u7968",
#                 "\u6613\u65b9\u8fbe\u88d5\u7965\u56de\u62a5\u503a\u5238",
#                 "\u6613\u65b9\u8fbe\u4e30\u548c\u503a\u5238",
#                 "\u5b89\u4fe1\u7a33\u5065\u589e\u503c\u6df7\u5408A",
#                 "\u9e4f\u534e\u4e30\u7984\u503a\u5238",
#                 "\u5e7f\u53d1\u8d8b\u52bf\u4f18\u9009\u7075\u6d3b\u914d\u7f6e\u6df7\u5408A",
#                 "\u6d77\u5bcc\u901a\u963f\u5c14\u6cd5\u5bf9\u51b2\u6df7\u5408A"
#             ],
#             "selected": {},
#             "type": "scroll",
#             "show": true,
#             "left": "left",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_c56e98f1053f478cbc442e8f4a31a820.setOption(option_c56e98f1053f478cbc442e8f4a31a820);
#         });
#     </script>

# %%
# 按大类分布的扇形图
sys.v_category_positions()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="f3454cacfb7344d9b06851572c5cb027" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_f3454cacfb7344d9b06851572c5cb027 = echarts.init(
#                     document.getElementById('f3454cacfb7344d9b06851572c5cb027'), 'white', {renderer: 'canvas'});
#                 var option_f3454cacfb7344d9b06851572c5cb027 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "name": "\u603b\u503c\u5360\u6bd4",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u503a\u5238\u57fa\u91d1",
#                     "value": 3759.23
#                 },
#                 {
#                     "name": "\u6df7\u5408\u57fa\u91d1",
#                     "value": 10390.7
#                 },
#                 {
#                     "name": "\u80a1\u7968\u57fa\u91d1",
#                     "value": 5525.89
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": false,
#                 "position": "center",
#                 "margin": 8
#             },
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "formatter": "{a} <br/>{b}: {c} ({d}%)",
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u503a\u5238\u57fa\u91d1",
#                 "\u6df7\u5408\u57fa\u91d1",
#                 "\u80a1\u7968\u57fa\u91d1"
#             ],
#             "selected": {},
#             "type": "scroll",
#             "show": true,
#             "left": "left",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_f3454cacfb7344d9b06851572c5cb027.setOption(option_f3454cacfb7344d9b06851572c5cb027);
#         });
#     </script>

# %%
## 底层股票持仓透视, 你其实可以通过这种方式来跟踪机构的股票池和抱团情况
sys.get_stock_holdings()
# Out:
#     name      code       value     ratio
# 0    万科A  SZ000002  410.282731  0.143297
# 1   格力电器  SZ000651  203.976064  0.071241
# 2   汇川技术  SZ300124  176.315109  0.061580
# 3   芒果超媒  SZ300413  171.180174  0.059787
# 4   隆基股份  SH601012  167.813061  0.058611
# 5   通策医疗  SH600763  148.379448  0.051824
# 6   绝味食品  SH603517  147.608152  0.051554
# 7   保利地产  SH600048  143.840528  0.050238
# 8   迈瑞医疗  SZ300760  136.430671  0.047650
# 9   华测检测  SZ300012  133.743380  0.046712
# 10  金地集团  SH600383  132.471320  0.046267
# 11  三花智控  SZ002050  132.252040  0.046191
# 12   广联达  SZ002410  129.705844  0.045302
# 13  中公教育  SZ002607  115.042480  0.040180
# 14  美亚柏科  SZ300188  106.597338  0.037231
# 15  中国平安  SH601318  105.052946  0.036691
# 16  紫金矿业  SH601899  101.604965  0.035487
# 17  中兴通讯  SZ000063  100.686054  0.035166
# 18  宇通客车  SH600066  100.183691  0.034991

# %%
sys.get_stock_holdings(date="2019-12-01", threhold=50)
# 可以调整透视的时间和股票阈值
# 可以看到2020以来格力平安等遭到组合的减持
# Out:
#     name      code       value     ratio
# 0   格力电器  SZ000651  392.117868  0.091499
# 1   中国平安  SH601318  237.493534  0.055418
# 2   华测检测  SZ300012  223.301951  0.052107
# 3   芒果超媒  SZ300413  214.607815  0.050078
# 4   美亚柏科  SZ300188  186.149699  0.043437
# 5   隆基股份  SH601012  164.401823  0.038363
# 6   三七互娱  SZ002555  145.223257  0.033887
# 7   星宇股份  SH601799  144.919955  0.033817
# 8   永辉超市  SH601933  133.115545  0.031062
# 9   中公教育  SZ002607  130.252046  0.030394
# 10  立讯精密  SZ002475  128.558051  0.029999
# 11   广联达  SZ002410  126.814240  0.029592
# 12  通策医疗  SH600763  125.142408  0.029202
# 13  国电南瑞  SH600406  116.941080  0.027288
# 14  华宇软件  SZ300271  113.862703  0.026569
# 15  平安银行  SZ000001  103.283090  0.024101
# 16  汇顶科技  SH603160  102.766070  0.023980
# 17  思创医惠  SZ300078   86.822915  0.020260
# 18  恒华科技  SZ300365   85.592354  0.019973
# 19  国瓷材料  SZ300285   83.042030  0.019378
# 20  我武生物  SZ300357   75.510311  0.017620
# 21  金地集团  SH600383   72.120475  0.016829
# 22  保利地产  SH600048   71.669896  0.016724
# 23  中兴通讯  SZ000063   70.682286  0.016493
# 24  绿盟科技  SZ300369   70.489165  0.016448
# 25  贵州茅台  SH600519   70.027050  0.016341
# 26   吉比特  SH603444   66.599400  0.015541
# 27  恩捷股份  SZ002812   66.218832  0.015452
# 28   欣旺达  SZ300207   65.547278  0.015295
# 29  游族网络  SZ002174   64.950272  0.015156
# 30  山东药玻  SH600529   62.895340  0.014676
# 31  歌尔股份  SZ002241   56.536920  0.013193
# 32  药明康德  SH603259   56.403320  0.013162
# 33  华兰生物  SZ002007   55.092904  0.012856
# 34  长安汽车  SZ000625   54.421224  0.012699
# 35  招商银行  SH600036   53.831005  0.012561
# 36  广发证券  SZ000776   53.533232  0.012492
# 37  晨光文具  SH603899   52.804951  0.012322
# 38  亿联网络  SZ300628   51.190844  0.011945
# 39   爱柯迪  SH600933   50.534564  0.011792

# %%
# 我们可以查看整个组合最底层具体的股票，债券，现金的仓位分布情况
sys.get_portfolio()
# 可以看到基本上股债平衡
# Out:
# {'bond': 8446.478429, 'cash': 1416.611418, 'stock': 10343.429751}

# %%
# 可以查看单只的买入卖出情况
sys.fundtradeobj[1].v_tradecost()
# 图上的蓝点对应一次现金分红
# 关于如何设定账单，以控制每次分红选择分红再投入还是现金分红，请参考文档
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="b8a9020fdf524f3ba6f72099d8ce4f65" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_b8a9020fdf524f3ba6f72099d8ce4f65 = echarts.init(
#                     document.getElementById('b8a9020fdf524f3ba6f72099d8ce4f65'), 'white', {renderer: 'canvas'});
#                 var option_b8a9020fdf524f3ba6f72099d8ce4f65 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u57fa\u91d1\u51c0\u503c",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": false,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "2015-05-25",
#                     1.0
#                 ],
#                 [
#                     "2015-05-28",
#                     1.0
#                 ],
#                 [
#                     "2015-05-29",
#                     1.0
#                 ],
#                 [
#                     "2015-06-01",
#                     1.0
#                 ],
#                 [
#                     "2015-06-02",
#                     1.001
#                 ],
#                 [
#                     "2015-06-03",
#                     1.001
#                 ],
#                 [
#                     "2015-06-04",
#                     1.001
#                 ],
#                 [
#                     "2015-06-05",
#                     1.001
#                 ],
#                 [
#                     "2015-06-08",
#                     1.002
#                 ],
#                 [
#                     "2015-06-09",
#                     1.002
#                 ],
#                 [
#                     "2015-06-10",
#                     1.002
#                 ],
#                 [
#                     "2015-06-11",
#                     1.002
#                 ],
#                 [
#                     "2015-06-12",
#                     1.002
#                 ],
#                 [
#                     "2015-06-15",
#                     1.002
#                 ],
#                 [
#                     "2015-06-16",
#                     1.001
#                 ],
#                 [
#                     "2015-06-17",
#                     1.002
#                 ],
#                 [
#                     "2015-06-18",
#                     1.001
#                 ],
#                 [
#                     "2015-06-19",
#                     1.001
#                 ],
#                 [
#                     "2015-06-23",
#                     1.001
#                 ],
#                 [
#                     "2015-06-24",
#                     1.001
#                 ],
#                 [
#                     "2015-06-25",
#                     1.001
#                 ],
#                 [
#                     "2015-06-26",
#                     1.001
#                 ],
#                 [
#                     "2015-06-29",
#                     1.002
#                 ],
#                 [
#                     "2015-06-30",
#                     1.002
#                 ],
#                 [
#                     "2015-07-01",
#                     1.002
#                 ],
#                 [
#                     "2015-07-02",
#                     1.002
#                 ],
#                 [
#                     "2015-07-03",
#                     1.002
#                 ],
#                 [
#                     "2015-07-06",
#                     1.002
#                 ],
#                 [
#                     "2015-07-07",
#                     1.002
#                 ],
#                 [
#                     "2015-07-08",
#                     1.002
#                 ],
#                 [
#                     "2015-07-09",
#                     1.003
#                 ],
#                 [
#                     "2015-07-10",
#                     1.003
#                 ],
#                 [
#                     "2015-07-13",
#                     1.003
#                 ],
#                 [
#                     "2015-07-14",
#                     1.002
#                 ],
#                 [
#                     "2015-07-15",
#                     1.0
#                 ],
#                 [
#                     "2015-07-16",
#                     1.005
#                 ],
#                 [
#                     "2015-07-17",
#                     1.007
#                 ],
#                 [
#                     "2015-07-20",
#                     1.008
#                 ],
#                 [
#                     "2015-07-21",
#                     1.008
#                 ],
#                 [
#                     "2015-07-22",
#                     1.009
#                 ],
#                 [
#                     "2015-07-23",
#                     1.01
#                 ],
#                 [
#                     "2015-07-24",
#                     1.01
#                 ],
#                 [
#                     "2015-07-27",
#                     1.009
#                 ],
#                 [
#                     "2015-07-28",
#                     1.008
#                 ],
#                 [
#                     "2015-07-29",
#                     1.008
#                 ],
#                 [
#                     "2015-07-30",
#                     1.008
#                 ],
#                 [
#                     "2015-07-31",
#                     1.008
#                 ],
#                 [
#                     "2015-08-03",
#                     1.008
#                 ],
#                 [
#                     "2015-08-04",
#                     1.01
#                 ],
#                 [
#                     "2015-08-05",
#                     1.012
#                 ],
#                 [
#                     "2015-08-06",
#                     1.011
#                 ],
#                 [
#                     "2015-08-07",
#                     1.011
#                 ],
#                 [
#                     "2015-08-10",
#                     1.012
#                 ],
#                 [
#                     "2015-08-11",
#                     1.011
#                 ],
#                 [
#                     "2015-08-12",
#                     1.01
#                 ],
#                 [
#                     "2015-08-13",
#                     1.013
#                 ],
#                 [
#                     "2015-08-14",
#                     1.013
#                 ],
#                 [
#                     "2015-08-17",
#                     1.014
#                 ],
#                 [
#                     "2015-08-18",
#                     1.014
#                 ],
#                 [
#                     "2015-08-19",
#                     1.014
#                 ],
#                 [
#                     "2015-08-20",
#                     1.014
#                 ],
#                 [
#                     "2015-08-21",
#                     1.015
#                 ],
#                 [
#                     "2015-08-24",
#                     1.015
#                 ],
#                 [
#                     "2015-08-25",
#                     1.014
#                 ],
#                 [
#                     "2015-08-26",
#                     1.015
#                 ],
#                 [
#                     "2015-08-27",
#                     1.016
#                 ],
#                 [
#                     "2015-08-28",

# %% [markdown]
# 做成封闭现金流系统则有更多可能性

# %%
sysfix = xa.mulfix(status=df, totmoney=14000)
# 做成有14000初始基金的封闭组合

# %%
sysfix.bcmkset(xa.vinfo("SH000300"), start="2017-01-01") # 设定比较基准为沪深300
# 这一过程会生成计算封闭组合每日净值情况，耗时较长，请耐心等待

# %%
sysfix.v_netvalue()
# 吊打300，毕竟马后炮的最强基金
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="4239beb4e22b44f8a9c810b8cc05a95a" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_4239beb4e22b44f8a9c810b8cc05a95a = echarts.init(
#                     document.getElementById('4239beb4e22b44f8a9c810b8cc05a95a'), 'white', {renderer: 'canvas'});
#                 var option_4239beb4e22b44f8a9c810b8cc05a95a = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u57fa\u91d1\u7ec4\u5408",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": false,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "2019-05-06",
#                     1.0
#                 ],
#                 [
#                     "2019-05-07",
#                     1.0085939527696077
#                 ],
#                 [
#                     "2019-05-08",
#                     1.0035654794797515
#                 ],
#                 [
#                     "2019-05-09",
#                     0.9967593778414368
#                 ],
#                 [
#                     "2019-05-10",
#                     1.01680114358864
#                 ],
#                 [
#                     "2019-05-13",
#                     1.0110672982831972
#                 ],
#                 [
#                     "2019-05-14",
#                     1.0079203849672842
#                 ],
#                 [
#                     "2019-05-15",
#                     1.0201127572946653
#                 ],
#                 [
#                     "2019-05-16",
#                     1.0221323248368754
#                 ],
#                 [
#                     "2019-05-17",
#                     1.0087410472559495
#                 ],
#                 [
#                     "2019-05-20",
#                     1.0023449927957777
#                 ],
#                 [
#                     "2019-05-21",
#                     1.0092658167747917
#                 ],
#                 [
#                     "2019-05-22",
#                     1.0101103322234042
#                 ],
#                 [
#                     "2019-05-23",
#                     0.9979037615865304
#                 ],
#                 [
#                     "2019-05-24",
#                     0.9971359170091771
#                 ],
#                 [
#                     "2019-05-27",
#                     1.0045122227567094
#                 ],
#                 [
#                     "2019-05-28",
#                     1.0083980160986112
#                 ],
#                 [
#                     "2019-05-29",
#                     1.007024187672119
#                 ],
#                 [
#                     "2019-05-30",
#                     1.0042004278802548
#                 ],
#                 [
#                     "2019-05-31",
#                     1.0045139265538487
#                 ],
#                 [
#                     "2019-06-03",
#                     1.0016333735240146
#                 ],
#                 [
#                     "2019-06-04",
#                     0.9965611694409218
#                 ],
#                 [
#                     "2019-06-05",
#                     0.9960733155267602
#                 ],
#                 [
#                     "2019-06-06",
#                     0.990361051651746
#                 ],
#                 [
#                     "2019-06-10",
#                     0.996762785435715
#                 ],
#                 [
#                     "2019-06-11",
#                     1.0110934231726634
#                 ],
#                 [
#                     "2019-06-12",
#                     1.0073427977371303
#                 ],
#                 [
#                     "2019-06-13",
#                     1.0065562113912467
#                 ],
#                 [
#                     "2019-06-14",
#                     1.0014425482444358
#                 ],
#                 [
#                     "2019-06-17",
#                     1.000258977165143
#                 ],
#                 [
#                     "2019-06-18",
#                     1.0023285227567664
#                 ],
#                 [
#                     "2019-06-19",
#                     1.0114574678280506
#                 ],
#                 [
#                     "2019-06-20",
#                     1.023588503458424
#                 ],
#                 [
#                     "2019-06-21",
#                     1.030035671832769
#                 ],
#                 [
#                     "2019-06-24",
#                     1.0322415211955205
#                 ],
#                 [
#                     "2019-06-25",
#                     1.0282126088939347
#                 ],
#                 [
#                     "2019-06-26",
#                     1.0313368049146596
#                 ],
#                 [
#                     "2019-06-27",
#                     1.0388482785685607
#                 ],
#                 [
#                     "2019-06-28",
#                     1.0374273117545532
#                 ],
#                 [
#                     "2019-07-01",
#                     1.0540870401806477
#                 ],
#                 [
#                     "2019-07-02",
#                     1.0549054307397945
#                 ],
#                 [
#                     "2019-07-03",
#                     1.0487462040819573
#                 ],
#                 [
#                     "2019-07-04",
#                     1.0434178624956199
#                 ],
#                 [
#                     "2019-07-05",
#                     1.04717416725495
#                 ],
#                 [
#                     "2019-07-08",
#                     1.0357161314945198
#                 ],
#                 [
#                     "2019-07-09",
#                     1.035881399817012
#                 ],
#                 [
#                     "2019-07-10",
#                     1.0364368376843578
#                 ],
#                 [
#                     "2019-07-11",
#                     1.0366276629639366
#                 ],
#                 [
#                     "2019-07-12",
#                     1.0382121943032974
#                 ],
#                 [
#                     "2019-07-15",
#                     1.043566660779101
#                 ],
#                 [
#                     "2019-07-16",
#                     1.04083149843847
#                 ],
#                 [
#                     "2019-07-17",
#                     1.0410643507141464
#                 ],
#                 [
#                     "2019-07-18",
#                     1.033924304836569
#                 ],
#                 [
#                     "2019-07-19",
#                     1.038648934303286
#                 ],
#                 [
#                     "2019-07-22",
#                     1.039253214355286
#                 ],
#                 [
#                     "2019-07-23",
#                     1.0449779727426534
#                 ],
#                 [
#                     "2019-07-24",
#                     1.0516199419232348
#                 ],
#                 [
#                     "2019-07-25",
#                     1.054636798724197
#                 ],
#                 [
#                     "2019-07-26",
#                     1.0571408125862902

# %%
sysfix.summary()
# 我们看到此时出现了货币基金选项，这是因为默认现金分红会智能处理帮你买入货币基金
# Out:
#              基金名称    基金代码     当日净值    单位成本     持有份额      基金现值     基金总申购  \
# 14             总计   total      NaN     NaN      NaN  21948.45  16331.49
# 13           货币基金      mf  1.35552  1.2395  1881.03   2549.77   3331.49
# 12       嘉实新兴产业股票  000751  3.57600  1.4892   671.49   2401.25   1000.00
# 8    交银定期支付双息平衡混合  519732  4.21000  2.0931   477.75   2011.33   1000.00
# 9      兴全商业模式优选混合  163415  2.43700  1.3781   725.65   1768.41   1000.00
# 6       易方达安心回馈混合  001182  1.86600  1.0981   910.67   1699.31   1000.00
# 7        交银优势行业混合  519697  4.27100  2.5531   365.88   1562.67   1000.00
# 11      中欧时代先锋股票A  001938  1.62160  0.7368   916.06   1485.48   1000.00
# 10      前海开源再融资股票  001178  1.62500  0.9057   888.35   1443.57   1000.00
# 5       易方达裕祥回报债券  002351  1.44500  1.0230   977.50   1412.49   1000.00
# 4         易方达丰和债券  002969  1.28140  1.0051   994.92   1274.89   1000.00
# 1       安信稳健增值混合A  001316  1.36160  1.0421   911.50   1241.10   1000.00
# 3          鹏华丰禄债券  003547  1.08980  0.8525   999.50   1089.26   1000.00
# 0   广发趋势优选灵活配置混合A  000215  1.61340  1.1712   669.68   1080.46   1000.00
# 2     海富通阿尔法对冲混合A  519062  1.14000  0.8208   814.44    928.46   1000.00
#
#       历史最大占用    基金持有成本  基金分红与赎回       换手率   基金收益总额     投资收益率
# 14  14000.00  13999.99  2331.50  0.150329  7948.46   56.7747
# 13   2331.48   2331.48  1000.01  0.279287   218.29    9.3627
# 12   1000.00   1000.00     0.00  0.150329  1401.25  140.1250
# 8    1000.00   1000.00     0.00  0.150329  1011.33  101.1330
# 9    1000.00   1000.00     0.00  0.150329   768.41   76.8410
# 6    1000.00   1000.00     0.00  0.150329   699.31   69.9310
# 7    1000.00    934.14    65.86  0.160230   628.53   62.8530
# 11   1000.00    674.99   325.01  0.199188   810.49   81.0490
# 10   1000.00    804.56   195.44  0.179710   639.01   63.9010
# 5    1000.00   1000.00     0.00  0.150329   412.49   41.2490
# 4    1000.00   1000.00     0.00  0.150453   274.89   27.4890
# 1    1000.00    949.87    50.13  0.157866   291.23   29.1230
# 3    1000.00    852.07   147.93  0.172568   237.19   23.7190
# 0    1000.00    784.36   215.64  0.182747   296.10   29.6100
# 2    1000.00    668.52   331.48  0.200161   259.94   25.9940

# %% [markdown]
# 我们可以进一步进行指标分析

# %%
sysfix.beta(), sysfix.alpha(), sysfix.sharpe()
# Out:
# (0.508105417009912, 0.040867579213678853, 0.279802542882795)

# %%
sysfix.total_annualized_returns(), sysfix.algorithm_volatility()
# Out:
# (0.0684, 0.11160584774628288)

# %%
sysfix.max_drawdown()
# 最大回撤8%发生在今年，竟然不是18年，是不是说明马后炮组合的优势再减弱？
# Out:
# (Timestamp('2020-02-25 00:00:00'),
#  Timestamp('2020-03-23 00:00:00'),
#  -0.08257630349535526)
