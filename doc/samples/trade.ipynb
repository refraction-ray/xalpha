# %%
import sys
sys.path.insert(0, "../../")
from pyecharts import online
online()
#  演示必要的准备代码，使用该库时不需重复此单元格命令

# %%
import xalpha as xa
import pandas as pd

# %% [markdown]
# # 指定标的的交易分析

# %% [markdown]
# * 想要进行交易分析首先需要交易单

# %%
path='../../tests/demo.csv'

# %%
read = xa.record(path) 
# record 类用来从指定位置读取 csv 文件，并将交易单数据存储在 self.status 中
# 该类可直接接受 pd.read_csv() 的多样的关键字参数，比如 skiprows=1, 这样就可以在真实的记账单首行标注基金名称，而不影响程序处理

# %%
read.status 
#  一个示例的交易单演示
## 特别注意由于基金申购是按照金额，赎回是按照份额，因此交易单采用此惯例，正数代表申购金额，负数代表赎回份额
## 数据理论上小数点后两位有效，不过从第二位小数开始，数字起到了一些特殊标记的作用，因此仅完美支持一位小数，对于绝大多数人完全够用
## 金额是不需要考虑申购和赎回费的，简单记录您申购的总金额或赎回的份额，程序将完全充分的考虑所有申购赎回折算分红等情况，确保和真实持仓波动完全一致
## 在原始的 csv 形式中，0 不必要显式写出，直接空过去就好
## 小数点第二位的5，如果当天恰为该基金的登记分红日，则视为选择了分红再投入，否则默认分红拿现金
## 若负数绝对值小于 0.005，则视为赎回的份额比例而非份额数目， －0.005 表示清仓，依此线性缩放
## 更进一步的，非交易交易记录或是赎回份额超过持有总数， 程序都将作出协调自洽的处理
# Out:
#         date  001180   003376  100032   001469  164818
# 0 2016-09-28   200.0      0.0  700.00    0.000   270.0
# 1 2017-10-17   100.0    300.0  225.00    0.000     0.0
# 2 2017-12-12   -90.0    242.0  -80.00  380.000     0.0
# 3 2018-01-18     0.0      0.0  200.05  100.000     0.0
# 4 2018-07-05   300.0    200.0  770.00 -100.000   210.0
# 5 2018-07-26     0.0 -10000.0    0.00   -0.005     0.0

# %% [markdown]
# * 现在分析一下 001180 基金的交易情形

# %%
f = xa.fundinfo('001180')

# %%
f
# Out:
# 广发医药卫生联接A

# %%
f_t = xa.trade(f, read.status) # 给定标的和账单，交易就生成了

# %%
f_t.aim # 查看该交易的标的
# Out:
# 广发医药卫生联接A

# %%
f_t.dailyreport()  # 该交易截止昨天的信息总结，也可以给定'2018-01-01'形式的时间参数，来了解任意一天的基金持有概况
# Out:
#         基金名称    基金代码    当日净值   单位成本    持有份额    基金现值  基金总申购  历史最大占用  基金持有成本  \
# 0  广发医药卫生联接A  001180  0.7721  0.831  630.39  486.72  600.0  523.86  523.86
#
#    基金分红与赎回       换手率  基金收益总额   投资收益率
# 0    76.14  0.346908  -37.14 -7.0897

# %%
f_t.xirrrate('2018-07-01') # 计算截止7.1的 xirr 收益率，最客观的年化收益指标
# Out:
# 0.04879311024975706

# %%
f_t.v_totvalue() # 基金持有金额的变动可视化
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="c3bebde6e30244ab94285bbb9fe4cddf" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_c3bebde6e30244ab94285bbb9fe4cddf = echarts.init(document.getElementById('c3bebde6e30244ab94285bbb9fe4cddf'), 'light', {renderer: 'canvas'});
#
# var option_c3bebde6e30244ab94285bbb9fe4cddf = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 8297111,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "totvalue",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "2016-09-28T00:00:00",
#                     199.76
#                 ],
#                 [
#                     "2016-09-29T00:00:00",
#                     200.52
#                 ],
#                 [
#                     "2016-09-30T00:00:00",
#                     201.61
#                 ],
#                 [
#                     "2016-10-10T00:00:00",
#                     205.86
#                 ],
#                 [
#                     "2016-10-11T00:00:00",
#                     206.48
#                 ],
#                 [
#                     "2016-10-12T00:00:00",
#                     206.6
#                 ],
#                 [
#                     "2016-10-13T00:00:00",
#                     206.2
#                 ],
#                 [
#                     "2016-10-14T00:00:00",
#                     206.03
#                 ],
#                 [
#                     "2016-10-17T00:00:00",
#                     205.12
#                 ],
#                 [
#                     "2016-10-18T00:00:00",
#                     207.07
#                 ],
#                 [
#                     "2016-10-19T00:00:00",
#                     206.55
#                 ],
#                 [
#                     "2016-10-20T00:00:00",
#                     205.91
#                 ],
#                 [
#                     "2016-10-21T00:00:00",
#                     204.94
#                 ],
#                 [
#                     "2016-10-24T00:00:00",
#                     206.18
#                 ],
#                 [
#                     "2016-10-25T00:00:00",
#                     206.25
#                 ],
#                 [
#                     "2016-10-26T00:00:00",
#                     206.18
#                 ],
#                 [
#                     "2016-10-27T00:00:00",
#                     205.51
#                 ],
#                 [
#                     "2016-10-28T00:00:00",
#                     204.1
#                 ],
#                 [
#                     "2016-10-31T00:00:00",
#                     204.01
#                 ],
#                 [
#                     "2016-11-01T00:00:00",
#                     205.83
#                 ],
#                 [
#                     "2016-11-02T00:00:00",
#                     205.04
#                 ],
#                 [
#                     "2016-11-03T00:00:00",
#                     205.66
#                 ],
#                 [
#                     "2016-11-04T00:00:00",
#                     204.94
#                 ],
#                 [
#                     "2016-11-07T00:00:00",
#                     204.1
#                 ],
#                 [
#                     "2016-11-08T00:00:00",
#                     205.39
#                 ],
#                 [
#                     "2016-11-09T00:00:00",
#                     204.13
#                 ],
#                 [
#                     "2016-11-10T00:00:00",
#                     206.06
#                 ],
#                 [
#                     "2016-11-11T00:00:00",
#                     205.73
#                 ],
#                 [
#                     "2016-11-14T00:00:00",
#                     205.73
#                 ],
#                 [
#                     "2016-11-15T00:00:00",
#                     206.57
#                 ],
#                 [
#                     "2016-11-16T00:00:00",
#                     206.75
#                 ],
#                 [
#                     "2016-11-17T00:00:00",
#                     206.87
#                 ],
#                 [
#                     "2016-11-18T00:00:00",
#                     206.38
#                 ],
#                 [
#                     "2016-11-21T00:00:00",
#                     206.52
#                 ],
#                 [
#                     "2016-11-22T00:00:00",
#                     207.83
#                 ],
#                 [
#                     "2016-11-23T00:00:00",
#                     206.77
#                 ],
#                 [
#                     "2016-11-24T00:00:00",
#                     206.75
#                 ],
#                 [
#                     "2016-11-25T00:00:00",
#                     207.83
#                 ],
#                 [
#                     "2016-11-28T00:00:00",
#                     207.69
#                 ],
#                 [
#                     "2016-11-29T00:00:00",
#                     207.07
#                 ],
#                 [
#                     "2016-11-30T00:00:00",
#                     207.24
#                 ],
#                 [
#                     "2016-12-01T00:00:00",
#                     207.73
#                 ],
#                 [
#                     "2016-12-02T00:00:00",
#                     205.22
#                 ],
#                 [
#                     "2016-12-05T00:00:00",
#                     204.1
#                 ],
#                 [
#                     "2016-12-06T00:00:00",
#                     204.55
#                 ],
#                 [
#                     "2016-12-07T00:00:00",
#                     205.64
#                 ],
#                 [
#                     "2016-12-08T00:00:00",
#                     204.5
#                 ],
#                 [
#                     "2016-12-09T00:00:00",
#                     203.76
#                 ],
#                 [
#                     "2016-12-12T00:00:00",
#                     196.45
#                 ],
#                 [
#                     "2016-12-13T00:00:00",
#                     196.55
#                 ],
#                 [
#                     "2016-12-14T00:00:00",
#                     194.99
#                 ],
#                 [
#                     "2016-12-15T00:00:00",
#                     195.16
#                 ],
#                 [
#                     "2016-12-16T00:00:00",
#                     196.97
#                 ],
#                 [
#                     "2016-12-19T00:00:00",
#                     196.82
#                 ],
#                 [
#                     "2016-12-20T00:00:00",
#                     196.82
#                 ],
#                 [
#                     "2016-12-21T00:00:00",
#                     198.08
#                 ],
#                 [
#                     "2016-12-22T00:00:00",
#                     197.83
#                 ],
#                 [
#                     "2016-12-23T00:00:00",
#                     196.25
#                 ],

# %%
f_t.v_tradecost() # 同时比较基金净值和自己交易的单位成本的变动
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="e137c2aec720462c8a7e2496e2470abc" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_e137c2aec720462c8a7e2496e2470abc = echarts.init(document.getElementById('e137c2aec720462c8a7e2496e2470abc'), 'light', {renderer: 'canvas'});
#
# var option_e137c2aec720462c8a7e2496e2470abc = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 5104366,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "fundvalue",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "2015-05-06T00:00:00",
#                     1.0
#                 ],
#                 [
#                     "2015-05-08T00:00:00",
#                     1.0
#                 ],
#                 [
#                     "2015-05-15T00:00:00",
#                     1.0009
#                 ],
#                 [
#                     "2015-05-22T00:00:00",
#                     1.1173
#                 ],
#                 [
#                     "2015-05-27T00:00:00",
#                     1.1775
#                 ],
#                 [
#                     "2015-05-28T00:00:00",
#                     1.1154
#                 ],
#                 [
#                     "2015-05-29T00:00:00",
#                     1.1425
#                 ],
#                 [
#                     "2015-06-01T00:00:00",
#                     1.2038
#                 ],
#                 [
#                     "2015-06-02T00:00:00",
#                     1.2369
#                 ],
#                 [
#                     "2015-06-03T00:00:00",
#                     1.2367
#                 ],
#                 [
#                     "2015-06-04T00:00:00",
#                     1.2258
#                 ],
#                 [
#                     "2015-06-05T00:00:00",
#                     1.2338
#                 ],
#                 [
#                     "2015-06-08T00:00:00",
#                     1.2118
#                 ],
#                 [
#                     "2015-06-09T00:00:00",
#                     1.2031
#                 ],
#                 [
#                     "2015-06-10T00:00:00",
#                     1.2301
#                 ],
#                 [
#                     "2015-06-11T00:00:00",
#                     1.2562
#                 ],
#                 [
#                     "2015-06-12T00:00:00",
#                     1.2701
#                 ],
#                 [
#                     "2015-06-15T00:00:00",
#                     1.2374
#                 ],
#                 [
#                     "2015-06-16T00:00:00",
#                     1.1968
#                 ],
#                 [
#                     "2015-06-17T00:00:00",
#                     1.2117
#                 ],
#                 [
#                     "2015-06-18T00:00:00",
#                     1.1651
#                 ],
#                 [
#                     "2015-06-19T00:00:00",
#                     1.0999
#                 ],
#                 [
#                     "2015-06-23T00:00:00",
#                     1.1232
#                 ],
#                 [
#                     "2015-06-24T00:00:00",
#                     1.1385
#                 ],
#                 [
#                     "2015-06-25T00:00:00",
#                     1.0911
#                 ],
#                 [
#                     "2015-06-26T00:00:00",
#                     1.0043
#                 ],
#                 [
#                     "2015-06-29T00:00:00",
#                     0.9459
#                 ],
#                 [
#                     "2015-06-30T00:00:00",
#                     1.0024
#                 ],
#                 [
#                     "2015-07-01T00:00:00",
#                     0.9666
#                 ],
#                 [
#                     "2015-07-02T00:00:00",
#                     0.9196
#                 ],
#                 [
#                     "2015-07-03T00:00:00",
#                     0.8835
#                 ],
#                 [
#                     "2015-07-06T00:00:00",
#                     0.8699
#                 ],
#                 [
#                     "2015-07-07T00:00:00",
#                     0.8166
#                 ],
#                 [
#                     "2015-07-08T00:00:00",
#                     0.7889
#                 ],
#                 [
#                     "2015-07-09T00:00:00",
#                     0.8247
#                 ],
#                 [
#                     "2015-07-10T00:00:00",
#                     0.866
#                 ],
#                 [
#                     "2015-07-13T00:00:00",
#                     0.9076
#                 ],
#                 [
#                     "2015-07-14T00:00:00",
#                     0.9227
#                 ],
#                 [
#                     "2015-07-15T00:00:00",
#                     0.879
#                 ],
#                 [
#                     "2015-07-16T00:00:00",
#                     0.8978
#                 ],
#                 [
#                     "2015-07-17T00:00:00",
#                     0.9401
#                 ],
#                 [
#                     "2015-07-20T00:00:00",
#                     0.9471
#                 ],
#                 [
#                     "2015-07-21T00:00:00",
#                     0.9605
#                 ],
#                 [
#                     "2015-07-22T00:00:00",
#                     0.9643
#                 ],
#                 [
#                     "2015-07-23T00:00:00",
#                     0.9884
#                 ],
#                 [
#                     "2015-07-24T00:00:00",
#                     0.9696
#                 ],
#                 [
#                     "2015-07-27T00:00:00",
#                     0.895
#                 ],
#                 [
#                     "2015-07-28T00:00:00",
#                     0.8851
#                 ],
#                 [
#                     "2015-07-29T00:00:00",
#                     0.9181
#                 ],
#                 [
#                     "2015-07-30T00:00:00",
#                     0.883
#                 ],
#                 [
#                     "2015-07-31T00:00:00",
#                     0.8824
#                 ],
#                 [
#                     "2015-08-03T00:00:00",
#                     0.8707
#                 ],
#                 [
#                     "2015-08-04T00:00:00",
#                     0.9081
#                 ],
#                 [
#                     "2015-08-05T00:00:00",
#                     0.8987
#                 ],
#                 [
#                     "2015-08-06T00:00:00",
#                     0.8907
#                 ],
#                 [
#                     "2015-08-07T00:00:00",
#                     0.9126
#                 ],
#                 [
#                     "2015-08-10T00:00:00",
#                     0.9507
#                 ],
#                 [
#                     "2015-08-11T00:00:00",
#                     0.9451
#                 ],

# %%
f_t.v_tradevolume(bar_category_gap='85%') # 基金交易量的可视化
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="d73226119c0444b2a8af8b1ff2b5fa63" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_d73226119c0444b2a8af8b1ff2b5fa63 = echarts.init(document.getElementById('d73226119c0444b2a8af8b1ff2b5fa63'), 'light', {renderer: 'canvas'});
#
# var option_d73226119c0444b2a8af8b1ff2b5fa63 = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 104748,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u4e70\u5165",
#             "data": [
#                 [
#                     "2016-09-28T00:00:00",
#                     -200.0
#                 ],
#                 [
#                     "2017-10-17T00:00:00",
#                     -100.0
#                 ],
#                 [
#                     "2018-07-05T00:00:00",
#                     -300.0
#                 ]
#             ],
#             "barCategoryGap": "85%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 104748
#         },
#         {
#             "type": "bar",
#             "name": "\u5356\u51fa",
#             "data": [
#                 [
#                     "2017-12-12T00:00:00",
#                     76.14
#                 ]
#             ],
#             "barCategoryGap": "85%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 104748
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4e70\u5165",
#                 "\u5356\u51fa"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "time",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 0
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "dataZoom": [
#         {
#             "show": true,
#             "type": "slider",
#             "start": 50,
#             "end": 100,
#             "orient": "horizontal"
#         }
#     ]
# };
# myChart_d73226119c0444b2a8af8b1ff2b5fa63.setOption(option_d73226119c0444b2a8af8b1ff2b5fa63);
#
#     });
# </script>

# %% [markdown]
# 其他基金的交易分析同理。除了基金，指数类和货币基金类也可以作为交易标的进行交易和分析
